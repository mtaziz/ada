# %%
import numpy as np
import pandas as pd
import pyspark as ps
import matplotlib.pyplot as plt
import csv

import unicodedata

import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_json('reduced_tweets.json', lines=True)

# %%
word_vectorizer = CountVectorizer(ngram_range=(2, 3), analyzer='word', stop_words='english')

# %%
sparse_matrix = word_vectorizer.fit_transform(df[df.lang == 'en'].sample(n=100)['main'])
frequencies = sum(sparse_matrix).toarray()[0]

# %%
l = pd.DataFrame(frequencies, index=word_vectorizer.get_feature_names(), columns=['frequency'])

# %%
l
# Out:
#                                       frequency
# 10 appear                                     1
# 10 appear 2017                                1
# 196 057                                       1
# 1970 vlassis                                  1
# 1970 vlassis caniaris                         1
# 2018 minimum                                  1
# 2018 minimum stages                           1
# 20m yr                                        1
# 20m yr exact                                  1
# 224 calories                                  1
# 224 calories doing                            1
# 25 minutes                                    1
# 25 minutes bicycling                          1
# 3rd season                                    1
# 70s europe                                    1
# 70s europe galeriepeterkilchmann              1
# 90th min                                      1
# 90th min equaliser                            1
# actors characters                             1
# actors characters driving                     1
# actually spelled                              1
# actually spelled fucking                      1
# adam levine                                   1
# adam levine actually                          1
# adblock socialmedia                           1
# adblock socialmedia ruining                   1
# adorable human                                1
# adorable human beings                         1
# agreed language                               1
# agreed language previous                      1
# ...                                         ...
# wearing bibs                                  1
# wearing bibs ww                               1
# websites seo                                  1
# websites seo working                          1
# weekend warrior                               1
# weeks gonna                                   1
# weeks gonna stressfull                        1
# welp guess                                    1
# welp guess rape                               1
# whatsapp update                               1
# whatsapp update wherearetheredheads           1
# wherearetheredheads youmustbekidding          1
# ww yes                                        1
# ww yes pls                                    1
# ydo yo                                        1
# ydo yo life                                   1
# yeaah thanks                                  1
# yes pls                                       1
# yes pls read                                  1
# yes replaying                                 1
# yes single                                    1
# yes single day                                1
# yes wanks                                     1
# yes wanks furiously                           1
# yo life                                       1
# yo life andymore                              1
# yr exact                                      1
# yr exact hard                                 1
# θεά olympics                                  1
# θεά olympics rioolympics2016                  1
#
# [697 rows x 1 columns]
